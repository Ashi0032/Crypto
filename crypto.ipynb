# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp']=pd.to_datetime('today')
#df

# %%
import os
def api_runner():
  global df
  url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    #print(data)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)


  df = pd.json_normalize(data['data'])
  df['timestamp']=pd.to_datetime('today')
  df

  if not os.path.isfile(r"C:\Users\hp\OneDrive\Desktop\vs\data\Data-analyst\Crypto\API.csv"):
    df.to_csv(r"C:\Users\hp\OneDrive\Desktop\vs\data\Data-analyst\Crypto\API.csv",header='column_names')
  else:
    df.to_csv(r"C:\Users\hp\OneDrive\Desktop\vs\data\Data-analyst\Crypto\API.csv",mode='a',header=False)

# %%
import os
from time import time
from time import sleep
for i in range (333):
  api_runner()
  print("API Runner working")
  sleep(6)
exit()
# Out:
# API Runner working
# API Runner working
# API Runner working
# API Runner working
# API Runner working
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 7
#       5   api_runner()
#       6   print("API Runner working")
# ----> 7   sleep(6)
#       8 exit()
#
# KeyboardInterrupt:

# %%
df72=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\vs\data\Data-analyst\Crypto\API.csv")
df72
# Out:
#     Unnamed: 0    id             name symbol             slug  \
# 0            0     1          Bitcoin    BTC          bitcoin
# 1            1  1027         Ethereum    ETH         ethereum
# 2            2   825      Tether USDt   USDT           tether
# 3            3  1839              BNB    BNB              bnb
# 4            4    52              XRP    XRP              xrp
# 5            5  3408         USD Coin   USDC         usd-coin
# 6            6    74         Dogecoin   DOGE         dogecoin
# 7            7  2010          Cardano    ADA          cardano
# 8            8  5426           Solana    SOL           solana
# 9            9  1958             TRON    TRX             tron
# 10          10  3890          Polygon  MATIC          polygon
# 11          11     2         Litecoin    LTC         litecoin
# 12          12  6636         Polkadot    DOT     polkadot-new
# 13          13  5994        Shiba Inu   SHIB        shiba-inu
# ...

# %%
df
# Out:
#       id             name symbol             slug  num_market_pairs  \
# 0      1          Bitcoin    BTC          bitcoin             10383
# 1   1027         Ethereum    ETH         ethereum              7214
# 2    825      Tether USDt   USDT           tether             58472
# 3   1839              BNB    BNB              bnb              1555
# 4     52              XRP    XRP              xrp              1019
# 5   3408         USD Coin   USDC         usd-coin             13536
# 6     74         Dogecoin   DOGE         dogecoin               762
# 7   2010          Cardano    ADA          cardano               887
# 8   5426           Solana    SOL           solana               496
# 9   1958             TRON    TRX             tron               802
# 10  3890          Polygon  MATIC          polygon               795
# 11     2         Litecoin    LTC         litecoin               963
# 12  6636         Polkadot    DOT     polkadot-new               546
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id             name symbol             slug  num_market_pairs  \
# 0      1          Bitcoin    BTC          bitcoin             10383
# 1   1027         Ethereum    ETH         ethereum              7214
# 2    825      Tether USDt   USDT           tether             58472
# 3   1839              BNB    BNB              bnb              1555
# 4     52              XRP    XRP              xrp              1019
# 5   3408         USD Coin   USDC         usd-coin             13536
# 6     74         Dogecoin   DOGE         dogecoin               762
# 7   2010          Cardano    ADA          cardano               887
# 8   5426           Solana    SOL           solana               496
# 9   1958             TRON    TRX             tron               802
# 10  3890          Polygon  MATIC          polygon               795
# 11     2         Litecoin    LTC         litecoin               963
# 12  6636         Polkadot    DOT     polkadot-new               546
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                              0.06926                       0.31448
# Ethereum                             0.11674                       0.24993
# Tether USDt                          0.00162                      -0.04777
# BNB                                  0.13942                      -0.27216
# XRP                                  0.18262                      -1.50395
# USD Coin                            -0.00446                       0.00664
# Dogecoin                            -0.02580                      -0.75649
# Cardano                             -0.00053                      -0.23062
# Solana                               0.08936                       1.77005
# TRON                                 0.01932                      -0.51016
# Polygon                              0.03141                       0.64704
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin          quote.USD.percent_change_1h      0.06926
#                  quote.USD.percent_change_24h     0.31448
#                  quote.USD.percent_change_7d     -0.90385
#                  quote.USD.percent_change_30d    -3.67505
#                  quote.USD.percent_change_60d    10.30467
#                  quote.USD.percent_change_90d     5.41191
# Ethereum         quote.USD.percent_change_1h      0.11674
#                  quote.USD.percent_change_24h     0.24993
#                  quote.USD.percent_change_7d     -1.42597
#                  quote.USD.percent_change_30d    -1.24528
#                  quote.USD.percent_change_60d    -0.05793
#                  quote.USD.percent_change_90d    -0.21415
# Tether USDt      quote.USD.percent_change_1h      0.00162
#                  quote.USD.percent_change_24h    -0.04777
#                  quote.USD.percent_change_7d     -0.17494
#                  quote.USD.percent_change_30d    -0.20675
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                                 values
# name
# Bitcoin         quote.USD.percent_change_1h    0.06926
#                 quote.USD.percent_change_24h   0.31448
#                 quote.USD.percent_change_7d   -0.90385
#                 quote.USD.percent_change_30d  -3.67505
#                 quote.USD.percent_change_60d  10.30467
#                 quote.USD.percent_change_90d   5.41191
# Ethereum        quote.USD.percent_change_1h    0.11674
#                 quote.USD.percent_change_24h   0.24993
#                 quote.USD.percent_change_7d   -1.42597
#                 quote.USD.percent_change_30d  -1.24528
#                 quote.USD.percent_change_60d  -0.05793
#                 quote.USD.percent_change_90d  -0.21415
# Tether USDt     quote.USD.percent_change_1h    0.00162
#                 quote.USD.percent_change_24h  -0.04777
#                 quote.USD.percent_change_7d   -0.17494
#                 quote.USD.percent_change_30d  -0.20675
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#                name                       level_1    values
# 0           Bitcoin   quote.USD.percent_change_1h   0.06926
# 1           Bitcoin  quote.USD.percent_change_24h   0.31448
# 2           Bitcoin   quote.USD.percent_change_7d  -0.90385
# 3           Bitcoin  quote.USD.percent_change_30d  -3.67505
# 4           Bitcoin  quote.USD.percent_change_60d  10.30467
# 5           Bitcoin  quote.USD.percent_change_90d   5.41191
# 6          Ethereum   quote.USD.percent_change_1h   0.11674
# 7          Ethereum  quote.USD.percent_change_24h   0.24993
# 8          Ethereum   quote.USD.percent_change_7d  -1.42597
# 9          Ethereum  quote.USD.percent_change_30d  -1.24528
# 10         Ethereum  quote.USD.percent_change_60d  -0.05793
# 11         Ethereum  quote.USD.percent_change_90d  -0.21415
# 12      Tether USDt   quote.USD.percent_change_1h   0.00162
# 13      Tether USDt  quote.USD.percent_change_24h  -0.04777
# 14      Tether USDt   quote.USD.percent_change_7d  -0.17494
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#                name                percent_change    values
# 0           Bitcoin   quote.USD.percent_change_1h   0.06926
# 1           Bitcoin  quote.USD.percent_change_24h   0.31448
# 2           Bitcoin   quote.USD.percent_change_7d  -0.90385
# 3           Bitcoin  quote.USD.percent_change_30d  -3.67505
# 4           Bitcoin  quote.USD.percent_change_60d  10.30467
# 5           Bitcoin  quote.USD.percent_change_90d   5.41191
# 6          Ethereum   quote.USD.percent_change_1h   0.11674
# 7          Ethereum  quote.USD.percent_change_24h   0.24993
# 8          Ethereum   quote.USD.percent_change_7d  -1.42597
# 9          Ethereum  quote.USD.percent_change_30d  -1.24528
# 10         Ethereum  quote.USD.percent_change_60d  -0.05793
# 11         Ethereum  quote.USD.percent_change_90d  -0.21415
# 12      Tether USDt   quote.USD.percent_change_1h   0.00162
# 13      Tether USDt  quote.USD.percent_change_24h  -0.04777
# 14      Tether USDt   quote.USD.percent_change_7d  -0.17494
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#                name percent_change    values
# 0           Bitcoin             1h   0.06926
# 1           Bitcoin            24h   0.31448
# 2           Bitcoin             7d  -0.90385
# 3           Bitcoin            30d  -3.67505
# 4           Bitcoin            60d  10.30467
# 5           Bitcoin            90d   5.41191
# 6          Ethereum             1h   0.11674
# 7          Ethereum            24h   0.24993
# 8          Ethereum             7d  -1.42597
# 9          Ethereum            30d  -1.24528
# 10         Ethereum            60d  -0.05793
# 11         Ethereum            90d  -0.21415
# 12      Tether USDt             1h   0.00162
# 13      Tether USDt            24h  -0.04777
# 14      Tether USDt             7d  -0.17494
# 15      Tether USDt            30d  -0.20675
# 16      Tether USDt            60d  -0.20475
# 17      Tether USDt            90d  -0.24325
# 18              BNB             1h   0.13942
# 19              BNB            24h  -0.27216
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
#df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#                name  quote.USD.price                  timestamp
# 0           Bitcoin      29131.58346 2023-08-07 10:30:54.689005
# 1          Ethereum       1838.01025 2023-08-07 10:30:54.689005
# 2       Tether USDt          0.99824 2023-08-07 10:30:54.689005
# 3               BNB        243.64958 2023-08-07 10:30:54.689005
# 4               XRP          0.62606 2023-08-07 10:30:54.689005
# 5          USD Coin          0.99998 2023-08-07 10:30:54.689005
# 6          Dogecoin          0.07507 2023-08-07 10:30:54.689005
# 7           Cardano          0.29403 2023-08-07 10:30:54.689005
# 8            Solana         23.29731 2023-08-07 10:30:54.689005
# 9              TRON          0.07698 2023-08-07 10:30:54.689005
# 10          Polygon          0.67666 2023-08-07 10:30:54.689005
# 11         Litecoin         82.97090 2023-08-07 10:30:54.689005
# 12         Polkadot          5.02029 2023-08-07 10:30:54.689005
# 13        Shiba Inu          0.00001 2023-08-07 10:30:54.689005
# ...

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
